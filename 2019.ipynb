# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import re

# %%
data = pd.read_csv('2019.csv')
pd.set_option('display.max_columns', 33)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991 entries, 0 to 990
# Data columns (total 23 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Timestamp                                                                                             991 non-null    object
#  1   Age                                                                                                   869 non-null    float64
#  2   Gender                                                                                                977 non-null    object
#  3   City                                                                                                  977 non-null    object
#  4   Seniority level                                                                                       962 non-null    object
#  5   Position (without seniority)                                                                          976 non-null    object
#  6   Years of experience                                                                                   977 non-null    float64
#  7   Your main technology / programming language                                                           964 non-null    object
#  8   Yearly brutto salary (without bonus and stocks)                                                       976 non-null    float64
#  9   Yearly bonus                                                                                          524 non-null    float64
#  10  Yearly stocks                                                                                         197 non-null    float64
#  11  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country  594 non-null    float64
#  12  Yearly bonus one year ago. Only answer if staying in same country                                     250 non-null    float64
#  13  Yearly stocks one year ago. Only answer if staying in same country                                    136 non-null    float64
#  14  Number of vacation days                                                                               917 non-null    float64
#  15  Number of home office days per month                                                                  629 non-null    float64
#  16  Main language at work                                                                                 972 non-null    object
#  17  Company name                                                                                          252 non-null    object
#  18  Company size                                                                                          964 non-null    object
#  19  Company type                                                                                          946 non-null    object
#  20  Сontract duration                                                                                     948 non-null    object
#  21  Company business sector                                                                               835 non-null    object
#  22  0                                                                                                     0 non-null      float64
# dtypes: float64(11), object(12)
# memory usage: 178.2+ KB

# %%
data.describe()
# Out:
#               Age  Years of experience  \
# count  869.000000           977.000000
# mean    32.406214             8.497441
# std      5.232564             5.037995
# min     20.000000             0.000000
# 25%     29.000000             5.000000
# 50%     32.000000             8.000000
# 75%     35.000000            11.000000
# max     54.000000            30.000000
#
#        Yearly brutto salary (without bonus and stocks)  Yearly bonus  \
# count                                       976.000000    524.000000
# mean                                      72546.403689   7858.969466
# std                                       23509.316495  10367.038562
# min                                        6000.000000      0.000000
# 25%                                       60000.000000    275.000000
# 50%                                       70000.000000   5000.000000
# 75%                                       80050.000000  10000.000000
# max                                      216000.000000  80000.000000
#
#        Yearly stocks  \
# count     197.000000
# mean    13103.468629
# std     22644.679133
# min         0.000000
# 25%         1.000000
# 50%      2000.000000
# 75%     20000.000000
# max    140000.000000
#
#        Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country  \
# count                                         594.000000
# mean                                        65999.577441
# std                                         20467.994543
# min                                             0.000000
# 25%                                         55000.000000
# 50%                                         65000.000000
# 75%                                         75000.000000
# max                                        200000.000000
#
#        Yearly bonus one year ago. Only answer if staying in same country  \
# count                                         250.000000
# mean                                         8042.428000
# std                                         15097.821279
# min                                             0.000000
# 25%                                          1000.000000
# 50%                                          5000.000000
# 75%                                          8875.000000
# max                                        150000.000000
#
#        Yearly stocks one year ago. Only answer if staying in same country  \
# count                                         136.000000
# mean                                         4488.398603
# std                                         11662.130259
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.055000
# 75%                                          2250.000000
# max                                         80000.000000
#
#        Number of vacation days  Number of home office days per month    0
# count               917.000000                            629.000000  0.0
# mean                 27.955289                              6.496423  NaN
# std                   4.429231                             15.498719  NaN
# min                   5.000000                              0.000000  NaN
# 25%                  26.000000                              2.000000  NaN
# 50%                  28.000000                              4.000000  NaN
# 75%                  30.000000                              7.000000  NaN
# max                 100.000000                            365.000000  NaN

# %%
missing_values = data.isna()
print(missing_values[missing_values > 0])
# Out:
#     Timestamp   Age Gender City Seniority level Position (without seniority)  \
# 0         NaN   NaN    NaN  NaN             NaN                          NaN
# 1         NaN   NaN    NaN  NaN             NaN                          NaN
# 2         NaN  True    NaN  NaN             NaN                          NaN
# 3         NaN   NaN    NaN  NaN             NaN                          NaN
# 4         NaN   NaN    NaN  NaN             NaN                          NaN
# ..        ...   ...    ...  ...             ...                          ...
# 986       NaN   NaN    NaN  NaN             NaN                          NaN
# 987       NaN   NaN    NaN  NaN             NaN                          NaN
# 988       NaN   NaN    NaN  NaN             NaN                          NaN
# 989       NaN   NaN    NaN  NaN             NaN                          NaN
# 990       NaN   NaN    NaN  NaN             NaN                          NaN
#
#     Years of experience Your main technology / programming language  \
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
# 2                   NaN                                         NaN
# 3                   NaN                                         NaN
# 4                   NaN                                         NaN
# ..                  ...                                         ...
# 986                 NaN                                         NaN
# 987                 NaN                                         NaN
# 988                 NaN                                         NaN
# 989                 NaN                                         NaN
# 990                 NaN                                         NaN
#
#     Yearly brutto salary (without bonus and stocks) Yearly bonus  \
# 0                                               NaN          NaN
# 1                                               NaN         True
# 2                                               NaN         True
# 3                                               NaN         True
# 4                                               NaN         True
# ..                                              ...          ...
# 986                                             NaN          NaN
# 987                                             NaN          NaN
# 988                                             NaN          NaN
# 989                                             NaN          NaN
# 990                                             NaN         True
#
#     Yearly stocks  \
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# ..            ...
# 986           NaN
# 987           NaN
# 988          True
# 989          True
# 990          True
#
#     Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 True
# 4                                                  NaN
# ..                                                 ...
# 986                                                NaN
# 987                                                NaN
# 988                                                NaN
# 989                                                NaN
# 990                                               True
#
#     Yearly bonus one year ago. Only answer if staying in same country  \
# 0                                                  NaN
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 986                                                NaN
# 987                                                NaN
# 988                                                NaN
# 989                                                NaN
# 990                                               True
#
#     Yearly stocks one year ago. Only answer if staying in same country  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 986                                                NaN
# 987                                                NaN
# 988                                               True
# 989                                               True
# 990                                               True
#
#     Number of vacation days Number of home office days per month  \
# 0                       NaN                                  NaN
# 1                       NaN                                  NaN
# 2                       NaN                                 True
# 3                       NaN                                 True
# 4                       NaN                                  NaN
# ..                      ...                                  ...
# 986                     NaN                                  NaN
# 987                     NaN                                  NaN
# 988                     NaN                                  NaN
# 989                     NaN                                  NaN
# 990                     NaN                                  NaN
#
#     Main language at work Company name  Company size Company type  \
# 0                     NaN          True          NaN          NaN
# 1                     NaN          True          NaN          NaN
# 2                     NaN          True          NaN          NaN
# 3                     NaN           NaN          NaN          NaN
# 4                     NaN           NaN          NaN          NaN
# ..                    ...           ...          ...          ...
# 986                   NaN          True          NaN          NaN
# 987                   NaN           NaN          NaN          NaN
# 988                   NaN           NaN          NaN          NaN
# 989                   NaN          True          NaN          NaN
# 990                   NaN          True          NaN          NaN
#
#     Сontract duration Company business sector     0
# 0                 NaN                     NaN  True
# 1                 NaN                     NaN  True
# 2                 NaN                    True  True
# 3                 NaN                     NaN  True
# 4                 NaN                     NaN  True
# ..                ...                     ...   ...
# 986               NaN                     NaN  True
# 987               NaN                     NaN  True
# 988               NaN                     NaN  True
# 989               NaN                     NaN  True
# 990               NaN                     NaN  True
#
# [991 rows x 23 columns]

# %%
data_cleaned = data.dropna()

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 23 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Timestamp                                                                                             0 non-null      object
#  1   Age                                                                                                   0 non-null      float64
#  2   Gender                                                                                                0 non-null      object
#  3   City                                                                                                  0 non-null      object
#  4   Seniority level                                                                                       0 non-null      object
#  5   Position (without seniority)                                                                          0 non-null      object
#  6   Years of experience                                                                                   0 non-null      float64
#  7   Your main technology / programming language                                                           0 non-null      object
#  8   Yearly brutto salary (without bonus and stocks)                                                       0 non-null      float64
#  9   Yearly bonus                                                                                          0 non-null      float64
#  10  Yearly stocks                                                                                         0 non-null      float64
#  11  Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country  0 non-null      float64
#  12  Yearly bonus one year ago. Only answer if staying in same country                                     0 non-null      float64
#  13  Yearly stocks one year ago. Only answer if staying in same country                                    0 non-null      float64
#  14  Number of vacation days                                                                               0 non-null      float64
#  15  Number of home office days per month                                                                  0 non-null      float64
#  16  Main language at work                                                                                 0 non-null      object
#  17  Company name                                                                                          0 non-null      object
#  18  Company size                                                                                          0 non-null      object
#  19  Company type                                                                                          0 non-null      object
#  20  Сontract duration                                                                                     0 non-null      object
#  21  Company business sector                                                                               0 non-null      object
#  22  0                                                                                                     0 non-null      float64
# dtypes: float64(11), object(12)
# memory usage: 0.0+ bytes

# %%
missing_values = data_cleaned.isna()
print(missing_values[missing_values > 0])
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, City, Seniority level, Position (without seniority), Years of experience, Your main technology / programming language, Yearly brutto salary (without bonus and stocks), Yearly bonus, Yearly stocks, Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country, Yearly bonus one year ago. Only answer if staying in same country, Yearly stocks one year ago. Only answer if staying in same country, Number of vacation days, Number of home office days per month, Main language at work, Company name , Company size, Company type, Сontract duration, Company business sector, 0]
# Index: []

# %%
data_cleaned.describe()
# Out:
#        Age  Years of experience  \
# count  0.0                  0.0
# mean   NaN                  NaN
# std    NaN                  NaN
# min    NaN                  NaN
# 25%    NaN                  NaN
# 50%    NaN                  NaN
# 75%    NaN                  NaN
# max    NaN                  NaN
#
#        Yearly brutto salary (without bonus and stocks)  Yearly bonus  \
# count                                              0.0           0.0
# mean                                               NaN           NaN
# std                                                NaN           NaN
# min                                                NaN           NaN
# 25%                                                NaN           NaN
# 50%                                                NaN           NaN
# 75%                                                NaN           NaN
# max                                                NaN           NaN
#
#        Yearly stocks  \
# count            0.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
#
#        Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        Yearly bonus one year ago. Only answer if staying in same country  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        Yearly stocks one year ago. Only answer if staying in same country  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        Number of vacation days  Number of home office days per month    0
# count                      0.0                                   0.0  0.0
# mean                       NaN                                   NaN  NaN
# std                        NaN                                   NaN  NaN
# min                        NaN                                   NaN  NaN
# 25%                        NaN                                   NaN  NaN
# 50%                        NaN                                   NaN  NaN
# 75%                        NaN                                   NaN  NaN
# max                        NaN                                   NaN  NaN

# %%
data_cleaned.head()
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, City, Seniority level, Position (without seniority), Years of experience, Your main technology / programming language, Yearly brutto salary (without bonus and stocks), Yearly bonus, Yearly stocks, Yearly brutto salary (without bonus and stocks) one year ago. Only answer if staying in same country, Yearly bonus one year ago. Only answer if staying in same country, Yearly stocks one year ago. Only answer if staying in same country, Number of vacation days, Number of home office days per month, Main language at work, Company name , Company size, Company type, Сontract duration, Company business sector, 0]
# Index: []

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
age = data_cleaned['Age']
salary = data_cleaned['Yearly brutto salary (without bonus and stocks)']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(age, salary, alpha=0.5, color='blue')

plt.title('Scatter Plot of Age vs. Current Salary')
plt.xlabel('Age')
plt.ylabel('Current Salary')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hexbin(age, salary, gridsize=25, cmap='YlGnBu')  

plt.title('Hexbin Plot of Age vs. Current Salary')
plt.xlabel('Age')
plt.ylabel('Current Salary')
plt.colorbar(label='Counts')

plt.show()

# %%
age = data_cleaned['Age']
experience = data_cleaned['Years of experience']

plt.figure(figsize=(10, 6))
plt.scatter(age, experience, c='blue', alpha=0.5)  

plt.title('Scatter Plot of Age vs. Years of Experience')
plt.xlabel('Age')
plt.ylabel('Years of Experience')

plt.grid(True)
plt.show()

# %%
age = data_cleaned['Age']
experience = data_cleaned['Years of experience']
salary = data_cleaned['Yearly brutto salary (without bonus and stocks)']

plt.figure(figsize=(10, 6))
plt.plot(age, experience, label='Years of Experience', marker='o', linestyle='-')
plt.plot(age, salary, label='Current Salary', marker='x', linestyle='--')

plt.title('Bivariate Line Chart: Age vs. Years of Experience & Current Salary')
plt.xlabel('Age')
plt.ylabel('Value')
plt.legend()

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data_cleaned['Age'], bins=20, kde=True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data_cleaned, x='Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data_cleaned, x='Yearly brutto salary (without bonus and stocks)')
plt.xlabel('Salary')
plt.title('Salary Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data_cleaned, x='Years of experience', y='Yearly brutto salary (without bonus and stocks)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs. Years of Experience')
plt.show()
